# %%
#Imports

import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %%
#Gather the Data of BTC,ETH,SOL,ADA & Matic

btc_data = Path("Resources/BTC-USD.csv")
btc_df = pd.read_csv(btc_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
btc_df.rename(columns= {"Adj Close":"BTC"}, inplace=True)
btc_df.columns.name = "BTC"
btc_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3805/1039676126.py:4: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   btc_df = pd.read_csv(btc_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# BTC                Open         High          Low        Close          BTC  \
# Date
# 2018-11-02  6378.919922  6396.859863  6327.379883  6388.439941  6388.439941
# 2018-11-03  6387.240234  6400.069824  6342.370117  6361.259766  6361.259766
# 2018-11-04  6365.470215  6388.629883  6294.569824  6376.129883  6376.129883
# 2018-11-05  6363.620117  6480.589844  6363.620117  6419.660156  6419.660156
# 2018-11-06  6433.379883  6463.549805  6408.160156  6461.009766  6461.009766
#
# BTC             Volume
# Date
# 2018-11-02  4234870000
# 2018-11-03  3658640000
# 2018-11-04  4390020000
# 2018-11-05  4174800000
# 2018-11-06  4700040000

# %%
eth_data = Path("Resources/ETH-USD.csv")
eth_df = pd.read_csv(eth_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
eth_df.rename(columns= {"Adj Close":"ETH"}, inplace=True)
eth_df.columns.name = "ETH"
eth_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3805/85273761.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   eth_df = pd.read_csv(eth_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# ETH               Open        High         Low       Close         ETH  \
# Date
# 2018-11-02  198.981995  201.268997  198.755005  200.634995  200.634995
# 2018-11-03  200.740005  200.740005  199.524994  200.186005  200.186005
# 2018-11-04  200.158005  211.272003  198.985992  207.485992  207.485992
# 2018-11-05  207.100006  210.819000  206.572998  209.091003  209.091003
# 2018-11-06  209.473999  218.451996  207.893997  218.451996  218.451996
#
# ETH             Volume
# Date
# 2018-11-02  1451870000
# 2018-11-03  1307150000
# 2018-11-04  1749300000
# 2018-11-05  1613510000
# 2018-11-06  1856940000

# %%
sol_data = Path("Resources/SOL-USD.csv")
sol_df = pd.read_csv(sol_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
sol_df.rename(columns= {"Adj Close":"SOL"}, inplace=True)
sol_df.columns.name = "SOL"
sol_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3805/1347976147.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sol_df = pd.read_csv(sol_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# SOL             Open      High       Low     Close       SOL    Volume
# Date
# 2020-04-10  0.832005  1.313487  0.694187  0.951054  0.951054  87364276
# 2020-04-11  0.951054  1.049073  0.765020  0.776819  0.776819  43862444
# 2020-04-12  0.785448  0.956670  0.762426  0.882507  0.882507  38736897
# 2020-04-13  0.890760  0.891603  0.773976  0.777832  0.777832  18211285
# 2020-04-14  0.777832  0.796472  0.628169  0.661925  0.661925  16747614

# %%
ada_data = Path("Resources/ADA-USD.csv")
ada_df = pd.read_csv(ada_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
ada_df.rename(columns= {"Adj Close":"ADA"}, inplace=True)
ada_df.columns.name = "ADA"
ada_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3805/1156728066.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   ada_df = pd.read_csv(ada_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# ADA             Open      High       Low     Close       ADA    Volume
# Date
# 2018-11-02  0.070814  0.073040  0.070788  0.072584  0.072584  18823400
# 2018-11-03  0.072561  0.072621  0.070822  0.071479  0.071479  14948900
# 2018-11-04  0.071492  0.077307  0.071291  0.076229  0.076229  52924200
# 2018-11-05  0.075961  0.078880  0.074745  0.076148  0.076148  34358100
# 2018-11-06  0.076337  0.080952  0.076337  0.080952  0.080952  49473200

# %%
matic_data = Path("Resources/MATIC-USD.csv")
matic_df = pd.read_csv(matic_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
matic_df.rename(columns= {"Adj Close":"MATIC"}, inplace=True)
matic_df.columns.name = "MATIC"
matic_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_3805/532633894.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   matic_df = pd.read_csv(matic_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# MATIC           Open      High       Low     Close     MATIC    Volume
# Date
# 2019-04-28  0.004521  0.004545  0.004317  0.004421  0.004421   8408136
# 2019-04-29  0.004418  0.004492  0.003471  0.003471  0.003471   8267044
# 2019-04-30  0.003462  0.005078  0.003458  0.004478  0.004478  25072706
# 2019-05-01  0.004440  0.004673  0.004071  0.004374  0.004374  10567352
# 2019-05-02  0.004366  0.004700  0.004096  0.004198  0.004198   6714908

# %%
#Concatenate all Dataframes

all_crypto_df = pd.concat([btc_df, eth_df, sol_df, ada_df, matic_df], axis="columns", join="inner")
all_crypto_df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-04-10   7303.815430   7303.815430   6802.475098   6865.493164
# 2020-04-11   6867.440430   6926.069824   6789.920898   6859.083008
# 2020-04-12   6858.067871   7119.947266   6811.078125   6971.091797
# 2020-04-13   6965.616699   6965.616699   6668.259766   6845.037598
# 2020-04-14   6843.281738   6958.557129   6793.821289   6842.427734
# ...                  ...           ...           ...           ...
# 2023-10-29  34089.371094  34743.261719  33947.566406  34538.480469
# 2023-10-30  34531.742188  34843.933594  34110.972656  34502.363281
# 2023-10-31  34500.078125  34719.253906  34083.308594  34667.781250
# 2023-11-01  34657.273438  35527.929688  34170.691406  35437.253906
# 2023-11-02  35441.578125  35902.023438  34479.066406  34783.429688
#
#                      BTC       Volume         Open         High          Low  \
# Date
# 2020-04-10   6865.493164  43622840992   170.829269   170.949768   154.914474
# 2020-04-11   6859.083008  31222085946   158.538986   161.167572   155.298340
# 2020-04-12   6971.091797  35759567632   158.232391   164.516953   156.320511
# 2020-04-13   6845.037598  38619308647   160.720673   160.749695   151.614487
# 2020-04-14   6842.427734  34110434052   156.355957   160.944275   155.865936
# ...                  ...          ...          ...          ...          ...
# 2023-10-29  34538.480469  11160323986  1776.563965  1810.488647  1766.052979
# 2023-10-30  34502.363281  17184860315  1795.589111  1829.249512  1779.364502
# 2023-10-31  34667.781250  15758270810  1810.131592  1819.972656  1784.567627
# 2023-11-01  35437.253906  22446272005  1815.872070  1858.312866  1786.409546
# 2023-11-02  34783.429688  21160421376  1847.259888  1873.389404  1794.379395
#
#                   Close  ...       Low     Close       ADA     Volume  \
# Date                     ...
# 2020-04-10   158.412445  ...  0.032544  0.033215  0.033215   95977717
# 2020-04-11   158.216019  ...  0.032772  0.033354  0.033354   75648111
# 2020-04-12   161.142426  ...  0.033075  0.033806  0.033806   73751090
# 2020-04-13   156.279556  ...  0.032070  0.033107  0.033107   84000834
# 2020-04-14   157.596390  ...  0.032781  0.032974  0.032974   74633336
# ...                 ...  ...       ...       ...       ...        ...
# 2023-10-29  1795.546021  ...  0.289510  0.295283  0.295283  144390110
# 2023-10-30  1810.088623  ...  0.292755  0.302734  0.302734  222609453
# 2023-10-31  1816.458984  ...  0.287829  0.293107  0.293107  303875077
# 2023-11-01  1847.089722  ...  0.285319  0.307459  0.307459  334066110
# 2023-11-02  1795.965820  ...  0.301588  0.322529  0.322529  457311584
#
#                 Open      High       Low     Close     MATIC     Volume
# Date
# 2020-04-10  0.013550  0.013550  0.011590  0.012033  0.012033   23449295
# 2020-04-11  0.012033  0.012560  0.011868  0.012188  0.012188   17852262
# 2020-04-12  0.012172  0.012821  0.011926  0.012349  0.012349   15513362
# 2020-04-13  0.012316  0.012316  0.011619  0.012006  0.012006   11972524
# 2020-04-14  0.012013  0.012440  0.011854  0.012161  0.012161   17460651
# ...              ...       ...       ...       ...       ...        ...
# 2023-10-29  0.620640  0.641866  0.615319  0.638230  0.638230  163017931
# 2023-10-30  0.638249  0.649936  0.628216  0.649928  0.649928  254160422
# 2023-10-31  0.649966  0.656112  0.624971  0.635981  0.635981  298499867
# 2023-11-01  0.635974  0.668103  0.619803  0.668103  0.668103  331541961
# 2023-11-02  0.668195  0.686193  0.647743  0.657972  0.657972  359881600
#
# [1302 rows x 30 columns]

# %%
#Drop Columns

to_drop = ["Close",
          "Volume",
          "Open",
          "High",
          "Low"]

all_crypto_df.drop(to_drop, inplace=True, axis=1)
all_crypto_df.head()
# Out:
#                     BTC         ETH       SOL       ADA     MATIC
# Date
# 2020-04-10  6865.493164  158.412445  0.951054  0.033215  0.012033
# 2020-04-11  6859.083008  158.216019  0.776819  0.033354  0.012188
# 2020-04-12  6971.091797  161.142426  0.882507  0.033806  0.012349
# 2020-04-13  6845.037598  156.279556  0.777832  0.033107  0.012006
# 2020-04-14  6842.427734  157.596390  0.661925  0.032974  0.012161

# %%
#Calculate daily returns

daily_returns = all_crypto_df.pct_change().dropna()
daily_returns
# Out:
#                  BTC       ETH       SOL       ADA     MATIC
# Date
# 2020-04-11 -0.000934 -0.001240 -0.183202  0.004185  0.012881
# 2020-04-12  0.016330  0.018496  0.136052  0.013552  0.013210
# 2020-04-13 -0.018082 -0.030177 -0.118611 -0.020677 -0.027776
# 2020-04-14 -0.000381  0.008426 -0.149013 -0.004017  0.012910
# 2020-04-15 -0.029276 -0.027345 -0.023075 -0.033693 -0.043664
# ...              ...       ...       ...       ...       ...
# 2023-10-29  0.013168  0.010654  0.036941  0.013847  0.028343
# 2023-10-30 -0.001046  0.008099  0.065191  0.025233  0.018329
# 2023-10-31  0.004794  0.003519  0.101743 -0.031800 -0.021459
# 2023-11-01  0.022196  0.016863  0.076378  0.048965  0.050508
# 2023-11-02 -0.018450 -0.027678 -0.034403  0.049015 -0.015164
#
# [1301 rows x 5 columns]

# %%
all_crypto_df.plot(figsize=(20,10),
                  title="Crypto 2018-2023")
# Out:
# <Axes: title={'center': 'Crypto 2018-2023'}, xlabel='Date'>
