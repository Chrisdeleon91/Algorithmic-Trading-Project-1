# %%
#Importing Libraries 

import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib widget
# %matplotlib inline

# %%
#Gather the Data of BTC,ETH,SOL,ADA & Matic
# Data for Bitcoin

btc_data = Path("Resources/BTC-USD.csv")
btc_df = pd.read_csv(btc_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
btc_df.rename(columns= {"Adj Close":"BTC"}, inplace=True) # Changing ADJ CLose Column to Ticker
btc_df.columns.name = "BTC"
btc_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_7560/2944458696.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   btc_df = pd.read_csv(btc_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# BTC                Open         High          Low        Close          BTC  \
# Date
# 2020-04-10  7303.815430  7303.815430  6802.475098  6865.493164  6865.493164
# 2020-04-11  6867.440430  6926.069824  6789.920898  6859.083008  6859.083008
# 2020-04-12  6858.067871  7119.947266  6811.078125  6971.091797  6971.091797
# 2020-04-13  6965.616699  6965.616699  6668.259766  6845.037598  6845.037598
# 2020-04-14  6843.281738  6958.557129  6793.821289  6842.427734  6842.427734
#
# BTC               Volume
# Date
# 2020-04-10  4.362284e+10
# 2020-04-11  3.122209e+10
# 2020-04-12  3.575957e+10
# 2020-04-13  3.861931e+10
# 2020-04-14  3.411043e+10

# %%
# Data for Ethereum

eth_data = Path("Resources/ETH-USD.csv")
eth_df = pd.read_csv(eth_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
eth_df.rename(columns= {"Adj Close":"ETH"}, inplace=True) # Changing ADJ CLose Column to Ticker
eth_df.columns.name = "ETH"
eth_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_7560/1967173563.py:4: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   eth_df = pd.read_csv(eth_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# ETH               Open        High         Low       Close         ETH  \
# Date
# 2020-04-10  170.829269  170.949768  154.914474  158.412445  158.412445
# 2020-04-11  158.538986  161.167572  155.298340  158.216019  158.216019
# 2020-04-12  158.232391  164.516953  156.320511  161.142426  161.142426
# 2020-04-13  160.720673  160.749695  151.614487  156.279556  156.279556
# 2020-04-14  156.355957  160.944275  155.865936  157.596390  157.596390
#
# ETH               Volume
# Date
# 2020-04-10  1.798094e+10
# 2020-04-11  1.355509e+10
# 2020-04-12  1.512372e+10
# 2020-04-13  1.646528e+10
# 2020-04-14  1.472316e+10

# %%
# Data for Solana

sol_data = Path("Resources/SOL-USD.csv")
sol_df = pd.read_csv(sol_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
sol_df.rename(columns= {"Adj Close":"SOL"}, inplace=True)
sol_df.columns.name = "SOL"
sol_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_7560/3838828656.py:4: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sol_df = pd.read_csv(sol_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# SOL             Open      High       Low     Close       SOL      Volume
# Date
# 2020-04-10  0.832005  1.313487  0.694187  0.951054  0.951054  87364276.0
# 2020-04-11  0.951054  1.049073  0.765020  0.776819  0.776819  43862444.0
# 2020-04-12  0.785448  0.956670  0.762426  0.882507  0.882507  38736897.0
# 2020-04-13  0.890760  0.891603  0.773976  0.777832  0.777832  18211285.0
# 2020-04-14  0.777832  0.796472  0.628169  0.661925  0.661925  16747614.0

# %%
# Data for Cardano

ada_data = Path("Resources/ADA-USD.csv")
ada_df = pd.read_csv(ada_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
ada_df.rename(columns= {"Adj Close":"ADA"}, inplace=True) # Changing ADJ CLose Column to Ticker
ada_df.columns.name = "ADA"
ada_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_7560/1201301770.py:4: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   ada_df = pd.read_csv(ada_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# ADA             Open      High       Low     Close       ADA      Volume
# Date
# 2020-04-10  0.036162  0.036239  0.032544  0.033215  0.033215  95977717.0
# 2020-04-11  0.033215  0.034012  0.032772  0.033354  0.033354  75648111.0
# 2020-04-12  0.033329  0.034668  0.033075  0.033806  0.033806  73751090.0
# 2020-04-13  0.033782  0.033831  0.032070  0.033107  0.033107  84000834.0
# 2020-04-14  0.033123  0.033686  0.032781  0.032974  0.032974  74633336.0

# %%
# Data for Matic

matic_data = Path("Resources/MATIC-USD.csv")
matic_df = pd.read_csv(matic_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
matic_df.rename(columns= {"Adj Close":"MATIC"}, inplace=True) # Changing ADJ CLose Column to Ticker
matic_df.columns.name = "MATIC"
matic_df.head()
# Out:
# /var/folders/l6/y384x_5543jb99ssghwm02dm0000gn/T/ipykernel_7560/3873201934.py:4: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   matic_df = pd.read_csv(matic_data, index_col="Date", parse_dates=True, infer_datetime_format=True)
# MATIC           Open      High       Low     Close     MATIC      Volume
# Date
# 2020-04-10  0.013550  0.013550  0.011590  0.012033  0.012033  23449295.0
# 2020-04-11  0.012033  0.012560  0.011868  0.012188  0.012188  17852262.0
# 2020-04-12  0.012172  0.012821  0.011926  0.012349  0.012349  15513362.0
# 2020-04-13  0.012316  0.012316  0.011619  0.012006  0.012006  11972524.0
# 2020-04-14  0.012013  0.012440  0.011854  0.012161  0.012161  17460651.0

# %%
#Concat all data frames 

all_crypto_df = pd.concat([btc_df, eth_df, sol_df, ada_df, matic_df], axis="columns", join="inner")

# Display the Concatinated Data Frame

all_crypto_df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-04-10   7303.815430   7303.815430   6802.475098   6865.493164
# 2020-04-11   6867.440430   6926.069824   6789.920898   6859.083008
# 2020-04-12   6858.067871   7119.947266   6811.078125   6971.091797
# 2020-04-13   6965.616699   6965.616699   6668.259766   6845.037598
# 2023-11-06       NaN       NaN       NaN       NaN       NaN          NaN
# 2023-11-07  0.735448  0.735448  0.724242  0.727729  0.727729  295311616.0
#
# [1307 rows x 30 columns]

# %%
#Drop Columns
to_drop = ["Close",
          "Volume",
          "Open",
          "High",
          "Low"]

# Displaying the Data Frame 
all_crypto_df.drop(to_drop, inplace=True, axis=1)
all_crypto_df.head()
# Out:
#                     BTC         ETH       SOL       ADA     MATIC
# Date
# 2020-04-10  6865.493164  158.412445  0.951054  0.033215  0.012033
# 2020-04-11  6859.083008  158.216019  0.776819  0.033354  0.012188
# 2020-04-12  6971.091797  161.142426  0.882507  0.033806  0.012349
# 2020-04-13  6845.037598  156.279556  0.777832  0.033107  0.012006
# 2020-04-14  6842.427734  157.596390  0.661925  0.032974  0.012161

# %%
#Calculate daily returns
daily_returns = all_crypto_df.pct_change().dropna()

# Display the Daily Returns 

daily_returns
# Out:
#                  BTC       ETH       SOL       ADA     MATIC
# Date
# 2020-04-11 -0.000934 -0.001240 -0.183202  0.004185  0.012881
# 2020-04-12  0.016330  0.018496  0.136052  0.013552  0.013210
# 2020-04-13 -0.018082 -0.030177 -0.118611 -0.020677 -0.027776
# 2020-04-14 -0.000381  0.008426 -0.149013 -0.004017  0.012910
# 2020-04-15 -0.029276 -0.027345 -0.023075 -0.033693 -0.043664
# ...              ...       ...       ...       ...       ...
# 2023-11-03 -0.005894  0.017868 -0.017106  0.018193  0.016421
# 2023-11-04  0.010073  0.013588  0.071530 -0.001456  0.008825
# 2023-11-05 -0.000936  0.019626 -0.026165  0.043611  0.022807
# 2023-11-06  0.000000  0.000000  0.000000  0.000000  0.000000
# 2023-11-07 -0.002424 -0.000311  0.014398  0.053446  0.049610
#
# [1306 rows x 5 columns]

# %%
# Annualized Volatility of the Crypto Data

volatility = daily_returns.std() * np.sqrt(252)
volatility.sort_values(inplace=True)
volatility
# Out:
# BTC      0.527749
# ETH      0.692130
# ADA      0.840086
# MATIC    1.140006
# SOL      1.160723
# dtype: float64

# %%
# Ploting all Crypto Data 

all_crypto_df.plot(figsize=(15,8),
                  title="Crypto 2018-2023")
# Out:
# <Axes: title={'center': 'Crypto 2018-2023'}, xlabel='Date'>

# %%
# Moving Averages for Bitcoin

all_crypto_df['BTC_MA50'] = all_crypto_df['BTC'].rolling(window=50).mean()
all_crypto_df['BTC_MA200'] = all_crypto_df['BTC'].rolling(window=200).mean()
plt.plot(all_crypto_df.index, all_crypto_df['BTC'], label='BTC')
plt.plot(all_crypto_df.index, all_crypto_df['BTC_MA50'], label='BTC 50-day MA')
plt.plot(all_crypto_df.index, all_crypto_df['BTC_MA200'], label='BTC 200-day MA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BTC Moving Average Chart')
plt.legend()
plt.show()

# %%
# Moving Averages for ETH

all_crypto_df['ETH_MA50'] = all_crypto_df['ETH'].rolling(window=50).mean()
all_crypto_df['ETH_MA200'] = all_crypto_df['ETH'].rolling(window=200).mean()
plt.plot(all_crypto_df.index, all_crypto_df['ETH'], label='ETH')
plt.plot(all_crypto_df.index, all_crypto_df['ETH_MA50'], label='ETH 50-day MA')
plt.plot(all_crypto_df.index, all_crypto_df['ETH_MA200'], label='ETH 200-day MA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('ETH Moving Average Chart')
plt.legend()
plt.show()

# %%
# Moving averages for ADA

all_crypto_df['ADA_MA50'] = all_crypto_df['ADA'].rolling(window=50).mean()
all_crypto_df['ADA_MA200'] = all_crypto_df['ADA'].rolling(window=200).mean()
plt.plot(all_crypto_df.index, all_crypto_df['ADA'], label='ADA')
plt.plot(all_crypto_df.index, all_crypto_df['ADA_MA50'], label='ADA 50-day MA')
plt.plot(all_crypto_df.index, all_crypto_df['ADA_MA200'], label='ADA 200-day MA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('ADA Moving Average Chart')
plt.legend()
plt.show()

# %%
# Moving Averages for Matic

all_crypto_df['MATIC_MA50'] = all_crypto_df['MATIC'].rolling(window=50).mean()
all_crypto_df['MATIC_MA200'] = all_crypto_df['MATIC'].rolling(window=200).mean()
plt.plot(all_crypto_df.index, all_crypto_df['MATIC'], label='MATIC')
plt.plot(all_crypto_df.index, all_crypto_df['MATIC_MA50'], label='MATIC 50-day MA')
plt.plot(all_crypto_df.index, all_crypto_df['MATIC_MA200'], label='MATIC 200-day MA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('MATIC Moving Average Chart')
plt.legend()
plt.show()

# %%
# Moving Averages for SOL

all_crypto_df['SOL_MA50'] = all_crypto_df['SOL'].rolling(window=50).mean()
all_crypto_df['SOL_MA200'] = all_crypto_df['SOL'].rolling(window=200).mean()
plt.plot(all_crypto_df.index, all_crypto_df['SOL'], label='SOL')
plt.plot(all_crypto_df.index, all_crypto_df['SOL_MA50'], label='SOL 50-day MA')
plt.plot(all_crypto_df.index, all_crypto_df['SOL_MA200'], label='SOL 200-day MA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('SOL Moving Average Chart')
plt.legend()
plt.show()

# %%
# Correlation Heatmap

corr = all_crypto_df[['BTC', 'SOL', 'MATIC', 'ADA', 'ETH']].corr()
plt.imshow(corr, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns)
plt.title('Crypto Correlation Heatmap')
plt.show()

# %%
from datetime import datetime
import backtrader as bt
from backtrader import plot
import yfinance as yf

# %%
# Create a subclass of Strategy to define the indicators and logic

class SmaCross(bt.Strategy):
    # list of parameters which are configurable for the strategy
    params = dict(
        pfast=50,  # period for the fast moving average
        pslow=200   # period for the slow moving average
    )

    def __init__(self):
        sma1 = bt.ind.SMA(period=self.p.pfast)  # fast moving average
        sma2 = bt.ind.SMA(period=self.p.pslow)  # slow moving average
        self.crossover = bt.ind.CrossOver(sma1, sma2)  # crossover signal

    def next(self):
        if not self.position:  # not in the market
            if self.crossover > 0:  # if fast crosses slow to the upside
                self.buy()  # enter long

        elif self.crossover < 0:  # in the market & cross to the downside
            self.close()  # close long position


cerebro = bt.Cerebro()  # create a "Cerebro" engine instance
cerebro.broker.setcash(100000)
# Create a data feed
data = bt.feeds.PandasData(dataname=yf.download('KPITTECH.NS', '2019-01-01', '2021-07-06'))

cerebro.adddata(data)  # Add the data feed

cerebro.addstrategy(SmaCross)  # Add the trading strategy
cerebro.run()  # run it all

# %matplotlib widget
# %matplotlib inline
cerebro.plot(iplot=False, volume=False, savefig=True, figfilename='backtrader-plot.png')  # and plot it with a single command

print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Starting Portfolio Value: 100173.75
# Final Portfolio Value: 100173.75
